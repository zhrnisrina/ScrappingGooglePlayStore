# %% [markdown]
# # Panduan Lengkap Scraping Google Play Store dengan Python
#
# ---
#
# ## I. Tujuan Scraping Google Play Store
#
# Scraping dilakukan untuk mengambil berbagai informasi aplikasi seperti:
#
# - Nama aplikasi (`title`)
# - Developer
# - Kategori
# - Rating, jumlah review, jumlah unduhan
# - Deskripsi, ukuran, harga
# - Sumber keyword, koleksi, atau kategori
#
# ---
#
# ## II. Alat dan Library yang Digunakan
#
# ### 1. [`google-play-scraper`](https://pypi.org/project/google-play-scraper/)
# -  Mendukung: `search()`, `app()`, `reviews()`
# -  Tidak mendukung lagi: `collection()`, `category`
#
# ### 2. [`play_scraper`](https://github.com/danieliu/play-scraper) *(opsional)*
# - Mendukung `collection()` dan `category`
# - Terbatas, tidak aktif dikembangkan
#
# ---
#
# ## III. Opsi Strategi Scraping
#
# | Opsi Scraping | Deskripsi | Cocok untuk |
# |---------------|-----------|-------------|
# | **1. Kata Kunci (`search()`)** | Mencari aplikasi berdasarkan teks pencarian | Fleksibel dan aman |
# | **2. Koleksi (`collection()`)** | Koleksi seperti `'TOP_FREE'`, `'NEW_PAID'` (hanya via `play_scraper`) | Gunakan jika butuh simulasi koleksi |
# | **3. Kategori** | Contoh: `'PRODUCTIVITY'`, `'GAME_ACTION'` | Bisa disimulasikan dengan keyword |
# | **4. App ID** | Gunakan ID spesifik untuk ambil detail | Fokus aplikasi tertentu |
# | **5. Keyword × Koleksi (Simulasi)** | Kombinasikan keyword untuk meniru kategori & koleksi | Skala besar dan fleksibel |
#
# ---
#
# ## IV. Langkah-Langkah Scraping
#
# ### 🔹 1. Menentukan Tujuan dan Format Output
# - Apakah ingin semua aplikasi populer? edukasi? hanya game?
# - Output: CSV, JSON, atau MongoDB
#
# ---
#
# ### 🔹 2. Menyiapkan Keyword
#
# ```python
# keywords = ['vpn app', 'photo editor', 'finance tracker', 'language learning']
# ```
#
# ---
#
# ### 🔹 3. Scraping dengan `search()` dan `app()`
#
# ```python
# from google_play_scraper import search, app
#
# data = []
#
# results = search(query="vpn app", lang='en', country='us', n_hits=50)
# for r in results:
#     details = app(r['appId'], lang='en', country='us')
#     data.append(details)
# ```
#
# ---
#
# ### 🔹 4. Menyimpan Data
#
# ```python
# import json
# with open('output.json', 'w') as f:
#     json.dump(data, f, indent=4)
# ```
#
# Atau dalam CSV:
#
# ```python
# import pandas as pd
# pd.DataFrame(data).to_csv("output.csv", index=False)
# ```
#
# ---
#
# ### 🔹 5. Analisis & Insight (Opsional)
#
# Contoh insight yang bisa dianalisis:
# - Rata-rata rating per kategori
# - Jumlah aplikasi per keyword
# - Word frequency dari deskripsi
# - Aplikasi dengan unduhan terbanyak
#
# ---
#
# ## V. Kelebihan dan Keterbatasan
#
# | Aspek | Penjelasan |
# |-------|------------|
# | ✅ Mudah digunakan | Library siap pakai & dokumentasi jelas |
# | ✅ Info lengkap | `app()` menghasilkan detail yang kaya |
# | ⚠️ Tidak mendukung koleksi resmi | `collection()` deprecated di `google-play-scraper` |
# | ⚠️ Tanpa API resmi | Rentan rate-limit jika tidak hati-hati |
# | ⚠️ Batas jumlah hasil | Maksimal ±250 hasil per keyword |
#
# ---
#
# ## VI. Best Practice
#
# - Tambahkan `time.sleep(0.3)` antar request
# - Hindari keyword terlalu umum seperti `'application'`
# - Bersihkan dan verifikasi data (missing/null)
# - Gunakan keyword spesifik & relevan dengan target analisis

# %% [markdown]
# # **Deskripsi Proyek Scraping Data Google Play Store**
#
# ## **Judul**
# **Scraping dan Analisis Aplikasi Google Play Store Berdasarkan Koleksi dan Kategori**
#
# ---
#
# ## **Tujuan**
# Mengumpulkan data aplikasi dari Google Play Store dengan pendekatan berbasis keyword yang mencakup berbagai **koleksi** (seperti `TOP_FREE`, `NEW_PAID`) dan **kategori** (seperti `PRODUCTIVITY`, `GAME_ACTION`). Tujuan utama adalah:
# - Mengumpulkan metadata aplikasi populer
# - Menganalisis tren rating, review, dan distribusi kategori
# - Menyusun dataset untuk keperluan analisis lanjutan, seperti klasifikasi, visualisasi, atau insight bisnis
#
# ---
#
# ## **Apa yang Di-scrape**
# Untuk setiap aplikasi, data berikut dikumpulkan:
# - `app_name`: Nama aplikasi
# - `developer`: Nama pengembang
# - `category`: Kategori aplikasi
# - `rating`: Rating pengguna (0.0–5.0)
# - `number_of_reviews`: Jumlah ulasan
# - `number_of_downloads`: Jumlah unduhan (dalam format seperti `"1,000,000+"`)
# - `price`: Harga (biasanya `0` untuk aplikasi gratis)
# - `size`: Ukuran file aplikasi (jika tersedia)
# - `description`: Deskripsi singkat aplikasi
# - `app_id`: ID unik aplikasi di Play Store
# - `source_keyword`: Kata kunci scraping (koleksi/kategori yang digunakan)
#
# ---
#
# ## **Metode Scraping**
# - **Library**: `google-play-scraper`
# - **Metode**: Menggunakan fungsi `search()` untuk mendapatkan daftar aplikasi berdasarkan keyword, lalu fungsi `app()` untuk mengambil detailnya.
# - **Jumlah Data**: Hingga 68 keyword × 50 aplikasi = ± 3.400 aplikasi unik
# - **Bahasa & Lokasi**: English (`lang='en'`), Amerika Serikat (`country='us'`)
# - **Penyimpanan**: Data disimpan dalam format JSON (`google_play_scraped_20x68.json`)
#
# ---
#
# ## **Keterbatasan**
# - Tidak semua aplikasi yang ditampilkan benar-benar berasal dari koleksi/kategori karena `search()` bekerja berbasis keyword pencarian.
# - Beberapa aplikasi bisa muncul lebih dari satu kali pada keyword yang mirip (disaring dengan `app_id`).
# - Koleksi seperti `'TOP_FREE'` bukanlah parameter resmi untuk `search()`, tapi digunakan sebagai **simulasi keyword**.
#
# ---
#
# ## **Output yang Dihasilkan**
# - File JSON: `google_play_scraped_20x68.json` yang berisi metadata lengkap aplikasi
# - Dapat digunakan untuk analisis lebih lanjut seperti:
#   - Clustering kategori aplikasi
#   - Klasifikasi aplikasi populer
#   - Insight tren rating berdasarkan kategori

# %% [markdown]
# # **Sintaks Scraping Data Google Play Store**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install google-play-scraper
# Out:
# Collecting google-play-scraper
#   Downloading google_play_scraper-1.2.7-py3-none-any.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 1.8 MB/s eta 0:00:00
# Downloading google_play_scraper-1.2.7-py3-none-any.whl (28 kB)
# Installing collected packages: google-play-scraper
# Successfully installed google-play-scraper-1.2.7

# %%
from google_play_scraper import search, app
import json, time

keywords = [
    # Koleksi (14)
    'TOP_FREE', 'TOP_PAID', 'TOP_GROSSING', 'TRENDING',
    'NEW_FREE', 'NEW_PAID', 'NEW_FREE_GAMES', 'NEW_PAID_GAMES',
    'TOP_FREE_GAMES', 'TOP_PAID_GAMES', 'TOP_GROSSING_GAMES',
    'TOP_FREE_APPS', 'TOP_PAID_APPS', 'TOP_GROSSING_APPS',

    # Kategori Non-Game (34)
    'ART_AND_DESIGN', 'AUTO_AND_VEHICLES', 'BEAUTY', 'BOOKS_AND_REFERENCE',
    'BUSINESS', 'COMICS', 'COMMUNICATION', 'DATING', 'EDUCATION',
    'ENTERTAINMENT', 'EVENTS', 'FINANCE', 'FOOD_AND_DRINK',
    'HEALTH_AND_FITNESS', 'HOUSE_AND_HOME', 'LIBRARIES_AND_DEMO',
    'LIFESTYLE', 'MAPS_AND_NAVIGATION', 'MEDICAL', 'MUSIC_AND_AUDIO',
    'NEWS_AND_MAGAZINES', 'PARENTING', 'PERSONALIZATION', 'PHOTOGRAPHY',
    'PRODUCTIVITY', 'SHOPPING', 'SOCIAL', 'SPORTS', 'TOOLS',
    'TRAVEL_AND_LOCAL', 'VIDEO_PLAYERS', 'WEATHER',

    # Kategori Game & Family (20)
    'GAME', 'FAMILY', 'GAME_ACTION', 'GAME_ADVENTURE', 'GAME_ARCADE',
    'GAME_BOARD', 'GAME_CARD', 'GAME_CASINO', 'GAME_CASUAL',
    'GAME_EDUCATIONAL', 'GAME_MUSIC', 'GAME_PUZZLE', 'GAME_RACING',
    'GAME_ROLE_PLAYING', 'GAME_SIMULATION', 'GAME_SPORTS',
    'GAME_STRATEGY', 'GAME_TRIVIA', 'GAME_WORD',
    'FAMILY_ACTION', 'FAMILY_BRAINGAMES', 'FAMILY_CREATE'
]

all_apps = {}

for keyword in keywords:
    print(f"\nSearching: {keyword}")
    try:
        results = search(query=keyword, lang='en', country='us', n_hits=50)
        for idx, r in enumerate(results):
            app_id = r['appId']
            if app_id not in all_apps:
                try:
                    details = app(app_id, lang='en', country='us')
                    all_apps[app_id] = {
                        'app_name': details['title'],
                        'developer': details['developer'],
                        'category': details['genre'],
                        'rating': details.get('score'),
                        'number_of_reviews': details.get('reviews'),
                        'number_of_downloads': details.get('installs'),
                        'price': details.get('price'),
                        'size': details.get('size'),
                        'description': details.get('description'),
                        'app_id': app_id,
                        'source_keyword': keyword
                    }
                    print(f"  ✓ {idx+1}. {details['title']}")
                    time.sleep(0.3)
                except Exception as e:
                    print(f"Gagal ambil detail {app_id}: {e}")
    except Exception as e:
        print(f"Gagal search keyword {keyword}: {e}")
# Out:
# Searching: TOP_FREE
#   ✓ 1. Tinder Dating App: Chat & Date
#   ✓ 2. TextNow: Call + Text Unlimited
#   ✓ 3. Bumble Dating App: Meet & Date
#   ✓ 4. Free Fire MAX
#   ✓ 5. Hinge Dating App: Match & Date
#   ✓ 6. Royal Match
#   ✓ 7. Angry Birds 2
#   ✓ 8. Pandora - Music & Podcasts
#   ✓ 9. Cash App
#   ✓ 10. Gardenscapes
#   ✓ 11. Fishdom
#   ✓ 12. YouTube TV: Live TV & more
#   ✓ 13. Candy Crush Soda Saga
#   ✓ 14. Peacock TV: Stream TV & Movies
#   ✓ 15. Walmart: Shopping & Savings
#   ✓ 16. Google Voice
#   ✓ 17. Mario Kart Tour
#   ✓ 18. Tubi: Free Movies & Live TV
#   ✓ 19. Royal Kingdom
#   ✓ 20. SiriusXM: Music, Sports & News
#   ✓ 21. June's Journey: Hidden Objects
#   ✓ 22. Scrabble® GO-Classic Word Game
#   ✓ 23. Calm - Sleep, Meditate, Relax
#   ✓ 24. AVG AntiVirus & Security
#   ✓ 25. Microsoft To Do: Lists & Tasks
#   ✓ 26. Vita Mahjong
#   ✓ 27. Rocket Money - Bills & Budgets
#   ✓ 28. Fetch: America’s Rewards App
#   ✓ 29. Elevate - Brain Training Games
#   ✓ 30. The Weather Channel - Radar
#
# Searching: TOP_PAID
#   ✓ 1. Paid Keeper - Same Day Pay
#   ✓ 2. Posted: Get Paid to Create
#   ✓ 3. TopSurveys - Surveys for Cash
#   ✓ 4. Drumo: Get Paid With Real Cash
#   ✓ 5. Paid App - Get Paid Faster
#   ✓ 6. Get paid
#   ✓ 7. Paid app sales & Promocodes
#   ✓ 8. Instawork: Be your own boss
#   ✓ 9. TapResearch: Paid Surveys
#   ✓ 10. The Panel Station-Paid Surveys
#   ✓ 11. Paid App: Hire Skilled Pros
#   ✓ 12. PaidViewpoint
#   ✓ 13. Paid Apps Sales Pro
#   ✓ 14. Five Surveys - Earn Money Fast
#   ✓ 15. SurveyParty - Earn Cash Fast
#   ✓ 16. PaidCash: Play & Earn Money
#   ✓ 17. Kashup - Get paid daily
#   ✓ 18. Taskrabbit - Handyman, Errands
#   ✓ 19. PNC EarnedIt
#   ✓ 20. Toloka: Earn online
#   ✓ 21. Stardew Valley
#   ✓ 22. DailyPay On-Demand Pay
#   ✓ 23. Shiftsmart - Find Work
#   ✓ 24. Premise - Earn Money for Tasks
#   ✓ 25. Secret Shopper ®
#   ✓ 26. Paid Apps Sales
#   ✓ 27. Poll Pay: Earn Money & Cash
#   ✓ 28. Repocket - Make Money Daily
#   ✓ 29. Bloons TD 6
#   ✓ 30. BeMyEye - Earn money
#
# Searching: TOP_GROSSING
#   ✓ 1. Disney+
#   ✓ 4. PlutoTV: Live TV & Free Movies
#   ✓ 6. ReelShort - Stream Drama & TV
#   ✓ 7. Hulu: Stream TV shows & movies
#   ✓ 8. Angel: TV & Movies
#   ✓ 9. GoodShort - Movies & Dramas
#   ✓ 10. ShortMax - Watch Dramas & Show
#   ✓ 11. Pokémon GO
#   ✓ 12. Paramount+
#   ✓ 13. AMC+
#   ✓ 14. Apple TV
#   ✓ 15. Amazon Freevee: Free Movies/TV
#   ✓ 16. The NBC App - Stream TV Shows
#   ✓ 17. The Chosen
#   ✓ 18. StardustTV - Movies & Dramas
#   ✓ 19. DramaWave - Dramas&Movies
#   ✓ 20. My Drama: Short Stories & Reel
#   ✓ 21. AMC Theatres: Movies & More
#   ✓ 22. Philo: Shows, Movies, Live TV.
#   ✓ 23. NetShort - Popular Dramas & TV
#   ✓ 24. Spectrum TV
#   ✓ 25. Match Villains
#   ✓ 26. Telemundo: Series y TV en vivo
#   ✓ 27. DreameShort - Dramas and Shows
#   ✓ 28. Zeus
#   ✓ 29. IMDb: Movies & TV Shows
#   ✓ 30. Fandango at Home
#
# Searching: TRENDING
#   ✓ 1. Trending Viral Music Charts
#   ✓ 2. TradingView: Track All Markets
#   ✓ 3. Trending App | Viral Trends
#   ✓ 4. Audiomack: Music Downloader
#   ✓ 5. Threads
#   ✓ 6. SoundCloud: Play Music & Songs
#   ✓ 7. Pocket Broker - trading
#   ✓ 8. Instagram
#   ✓ 9. X
#   ✓ 10. Snapchat
#   ✓ 11. Spotify: Music and Podcasts
#   ✓ 12. Reddit
#   ✓ 13. YouTube
#   ✓ 14. Apple Music
#   ✓ 15. MetaTrader 5 — Forex, Stocks
#   ✓ 16. ChatGPT
#   ✓ 17. PayPal - Pay, Send, Save
#   ✓ 18. Google Meet
#   ✓ 19. LinkedIn: Jobs & Business News
#   ✓ 20. Facebook
#   ✓ 21. Candy Crush Saga
#   ✓ 22. Telegram
#   ✓ 23. Adobe Acrobat Reader: Edit PDF
#   ✓ 24. Microsoft Teams
#   ✓ 25. CapCut - Video Editor
#   ✓ 26. Investing.com: Stock Market
#   ✓ 27. Google Maps
#   ✓ 28. YouTube Music
#   ✓ 29. Canva: AI Photo & Video Editor
#   ✓ 30. Pinterest
#
# Searching: NEW_FREE
#   ✓ 1. Free Fire
#   ✓ 3. PUBG MOBILE
#   ✓ 4. Google Play Games
#   ✓ 5. Call of Duty: Mobile Season 4
#   ✓ 6. Clash of Clans
#   ✓ 8. Plex: Stream Movies & TV
#   ✓ 13. Honor of Kings
#   ✓ 14. Tango- Live Stream, Video Chat
#   ✓ 15. Zooba: Fun Battle Royale Games
#   ✓ 17. Bingo Blitz™️ - Bingo Games
#   ✓ 19. Temple Run 2: Endless Escape
#   ✓ 20. VPN Proton: Fast & Secure VPN
#   ✓ 22. War Robots Multiplayer Battles
#   ✓ 23. Piano Kids - Music & Songs
#   ✓ 24. NordVPN – fast VPN for privacy
#   ✓ 25. Telegram X
#   ✓ 26. Sniper 3D：Gun Shooting Games
#   ✓ 27. Quick Hit Casino Slots Games
#   ✓ 28. ExpressVPN: Fast & Secure VPN
#   ✓ 30. Fire Emblem Heroes
#
# Searching: NEW_PAID
#   ✓ 1. Retro Racing 2 Pro
#   ✓ 2. Last Survivor: Survival Pro
#   ✓ 3. Imperial Miners
#   ✓ 4. Simply You Icon Pack
#   ✓ 5. Dungeon Clawler
#   ✓ 6. AttaPoll - Paid Surveys
#   ✓ 7. Dead Cells
#   ✓ 8. EvoCreo 2: Monster Trainer RPG
#   ✓ 9. Brotato: Premium
#   ✓ 10. Crashlands 2
#   ✓ 11. Codenames
#   ✓ 12. Avalar: Shadow War Premium
#   ✓ 13. Simply Adaptive Icon Pack
#   ✓ 14. Endurance: dead space Premium
#   ✓ 15. Slime Legends - Survivor
#   ✓ 16. Vault of the Void
#   ✓ 17. Shambles: Sons of Apocalypse
#   ✓ 18. Refence: Roguelike Defence
#   ✓ 19. KR 1 - Emperor Simulator PRO
#   ✓ 20. Trivia Crack Premium Quiz Game
#   ✓ 21. [Premium] RPG Novel Rogue
#   ✓ 22. Bounty Of One: Premium
#   ✓ 23. Shadow Hunter: Offline Premium
#   ✓ 24. Streets of Rage 4
#   ✓ 25. Tokyo Debunker: Anime Romance
#   ✓ 26. Songs of Conquest Mobile
#   ✓ 27. A Perfect Day
#   ✓ 28. Townsmen Premium
#   ✓ 29. Space Stars: RPG Survival Pro
#   ✓ 30. Ares Arctic Minimal Icon Pack
#
# Searching: NEW_FREE_GAMES
#   ✓ 2. Slotomania™ Slots Casino Games
#   ✓ 16. Magic Jigsaw Puzzles－Games HD
#   ✓ 18. Art Puzzle - Jigsaw Art Games
#   ✓ 19. POP! Slots™
#   ✓ 20. Modern Combat 5: mobile FPS
#   ✓ 21. Kingshot
#   ✓ 22. Dream Mania - Match 3 Games
#   ✓ 24. Tile Story: Match Puzzle Game
#   ✓ 25. Cashman Casino Slots Games
#   ✓ 26. Harvest Land
#   ✓ 27. Dream Family - Match 3 Games
#   ✓ 28. Club Vegas Casino Slots Games
#   ✓ 29. Cash Frenzy™ - Casino Slots
#   ✓ 30. Story Match
#
# Searching: NEW_PAID_GAMES
#   ✓ 15. Survival Dungeon: Loot RPG Pro
#   ✓ 21. A Story of A Company
#   ✓ 25. PARAVOX ITC SYSTEM 4 PRO
#   ✓ 27. As Far As The Eye
#   ✓ 30. Shadow of Death: Dark Knight
#
# Searching: TOP_FREE_GAMES
#   ✓ 1. Balloon Master 3D-Puzzle Games
#   ✓ 2. Tile Club - Match Puzzle Game
#   ✓ 3. Solitaire - Classic Card Games
#   ✓ 4. Tile Explorer - Triple Match
#   ✓ 10. Wordscapes Search: Word Games
#   ✓ 11. Solitaire - Classic Card Games
#   ✓ 13. Tile Family®:Match Puzzle Game
#   ✓ 14. Word Search Explorer
#   ✓ 20. Goods Puzzle: Sort Challenge™
#   ✓ 24. Mahjong Triple - Match 3 Tile
#   ✓ 25. Bike Race：Motorcycle Games
#   ✓ 27. Lotsa Slots - Casino Games
#   ✓ 28. Hexa Sort
#   ✓ 29. Solitaire - Classic Card Games
#   ✓ 30. Qblock: Wood Block Puzzle Game
#
# Searching: TOP_PAID_GAMES
#   ✓ 2. Agent Walker (Full)
#   ✓ 4. Relic Bag: Shadow Hunter
#   ✓ 5. Grand Theft Auto: San Andreas
#   ✓ 6. Terraria
#   ✓ 7. Balatro
#   ✓ 8. Geometry Dash
#   ✓ 9. Slay the Spire
#   ✓ 10. Neo Monsters
#   ✓ 11. Kingdom Rush Origins TD
#   ✓ 12. Kingdom Rush Frontiers TD
#   ✓ 13. MONOPOLY
#   ✓ 14. Bloons TD 5
#   ✓ 16. Swagbucks Play Games + Surveys
#   ✓ 19. Shadow Fight 2 Special Edition
#   ✓ 20. EvoCreo - Pocket Monster Game
#   ✓ 21. Dawncaster: Deckbuilding RPG
#   ✓ 22. Evertale
#   ✓ 24. Animal Crossing: Pocket Camp C
#   ✓ 25. Mini Metro
#   ✓ 26. CHRONO TRIGGER (Upgrade Ver.)
#   ✓ 27. Botworld Adventure
#   ✓ 28. Lara Croft GO
#   ✓ 30. Kingdom Rush 5: Alliance TD
#   ✓ 31. Total War: MEDIEVAL II
#   ✓ 32. ReadEra Premium – ebook reader
#   ✓ 33. XX Century 2 Premium
#   ✓ 34. Lowriders Comeback: Boulevard
#   ✓ 35. Queen's Quest: Tower of Darkne
#   ✓ 36. Space Shooter: Galaxy Attack
#   ✓ 37. Empire Warrior: Tower Defense
#   ✓ 38. MA 2 – President Simulator PRO
#   ✓ 40. Pogo: Earn Cash & Rewards
#   ✓ 41. Hitman Sniper
#   ✓ 42. Cytus II
#   ✓ 45. Pro Wrestler Story
#   ✓ 47. OCTOPATH TRAVELER: CotC
#   ✓ 48. Pocket Rogues: Ultimate
#   ✓ 50. The Game of Life 2
#
# Searching: TOP_GROSSING_GAMES
#   ✓ 2. Word Collect - Word Games Fun
#   ✓ 3. Game of Thrones Slots Casino
#   ✓ 5. Candy Critters: Idle Merge
#   ✓ 6. The Price Is Right: Bingo!
#   ✓ 7. Nexomon: Extinction
#   ✓ 8. Pocket Tales: Survival Game
#   ✓ 9. Taps to Riches
#   ✓ 10. Pocket Necromancer
#   ✓ 11. Soul Of Ring: Revive
#   ✓ 12. Kurukshetra: Ascension
#   ✓ 13. Trading Legend
#   ✓ 14. Tiny Shop: Craft & Design
#   ✓ 15. Tycoon - Business Empires Game
#   ✓ 16. Trade Island
#   ✓ 17. God Hunting
#   ✓ 18. Eerie Worlds
#   ✓ 19. Mall Blitz
#   ✓ 20. Harvest101: Farm Deck Building
#   ✓ 21. Athene AI Heroes
#   ✓ 22. My Video Game Collection
#   ✓ 23. Magic Streets: Turn based RPG
#   ✓ 24. Auction City: Tycoon Simulator
#   ✓ 25. Eterspire - Fantasy MMORPG
#   ✓ 26. EXTOCIUM - NFT, P2E, MMORPG
#   ✓ 27. Ticket to Earth
#   ✓ 28. Quest Hunter
#   ✓ 29. Evidence 111 - Audio Game
#   ✓ 30. BoxedUp: Sneaker Trading Cards
#
# Searching: TOP_FREE_APPS
#   ✓ 19. Boo: Dating. Friends. Chat.
#   ✓ 24. Hidden City: Hidden Object
#   ✓ 25. Jewel Hunter - Match 3 Games
#   ✓ 26. Two Dots: Connect the dots
#   ✓ 27. OkCupid Dating: Date Singles
#   ✓ 30. Nextdoor: Neighborhood network
#
# Searching: TOP_PAID_APPS
#   ✓ 1. Demon Hunter 4 (Full)
#   ✓ 16. Threema. The Secure Messenger
#
# Searching: TOP_GROSSING_APPS
#   ✓ 2. Daily Sales Record
#   ✓ 3. Consumer Reports
#   ✓ 4. Accrue: The cross-border app
#   ✓ 5. Research 360: Market Research
#   ✓ 6. Crowdtap: Surveys & Rewards
#   ✓ 7. TopLogger
#   ✓ 8. GigSmart Get Gigs
#   ✓ 9. TOP TIER™  Station Finder
#   ✓ 10. Keepa - Amazon Price Tracker
#   ✓ 11. Topo Guru x theCrag
#   ✓ 12. Jiji Tanzania: Buy&Sell Online
#   ✓ 13. GoCharting
#   ✓ 14. Surveys On The Go
#
# Searching: ART_AND_DESIGN
#   ✓ 1. Squishy Magic: 3D Toy Coloring
#   ✓ 2. Crayola Create & Play
#   ✓ 3. Infinite Painter
#   ✓ 4. Concepts: Sketch, Note, Draw
#   ✓ 5. Design Home™: House Makeover
#   ✓ 6. FlipaClip: Create 2D Animation
#   ✓ 7. Sketch Pro: Draw & Create Art
#   ✓ 8. Pixel Art - Color by Number
#   ✓ 9. Clip Studio Paint
#   ✓ 10. Castle - Make and Pla‪y
#   ✓ 11. Happy Color®: Coloring Book
#   ✓ 12. Sketchbook
#   ✓ 13. Adobe Capture: Illustrator,Ps
#   ✓ 14. Makers Empire 3D - 3D Printing
#   ✓ 15. Magic Poser - Art Pose Tool
#   ✓ 16. Star Art: Drawing & Relaxing
#   ✓ 17. Hexa - AI Logo & Art Generator
#   ✓ 18. Adobe Express: AI Photo, Video
#   ✓ 19. Infinite Design
#   ✓ 20. Pixio®
#   ✓ 21. ibis Paint X
#   ✓ 22. Gencraft - AI Art Generator
#   ✓ 23. Design Space: DIY with Cricut
#   ✓ 24. Pixel Tap: Color by Number
#   ✓ 25. Redecor - Home Design Game
#   ✓ 26. TattooInk: AI Tattoo Generator
#   ✓ 27. ARTA: AI Art & Photo Generator
#   ✓ 28. Krita
#   ✓ 29. Tap Color Pro: Color By Number
#   ✓ 30. Color Oasis - Color by Number
#
# Searching: AUTO_AND_VEHICLES
#   ✓ 1. Mileage Tracker by MileageWise
#   ✓ 2. Edmunds - Shop Cars For Sale
#   ✓ 3. Zoomcar: Car rental for travel
#   ✓ 4. Revv - Self Drive Car Rentals
#   ✓ 5. IndusGo Self Drive Rent a Car
#   ✓ 6. Multiple Space; Parallel Apps
#   ✓ 7. St James Auto & Truck Parts-MO
#   ✓ 8. Dual, House of Multiple Apps
#   ✓ 9. Modern Car 3D: Driving School
#   ✓ 10. Gangster Thug Crime Mafia City
#   ✓ 11. Gangster Crime City Monster
#   ✓ 12. Real Mehran Car Parking Games
#   ✓ 13. Vegas Gangster Crime Simulator
#   ✓ 14. Car Experts
#
# Searching: BEAUTY
#   ✓ 1. YouCam Perfect - Photo Editor
#   ✓ 2. YouCam Makeup - Selfie Editor
#   ✓ 3. Monster High™ Beauty Salon
#   ✓ 4. BeautyPlus-Selfie Film Camera
#   ✓ 5. Ulta Beauty: Makeup & Skincare
#   ✓ 6. Beauty Tiles: Story & Makeover
#   ✓ 7. Sephora: Buy Makeup & Skincare
#   ✓ 8. Beauty Tycoon: Haircut Salon
#   ✓ 9. BeautyCam-AI Photo Editor
#   ✓ 10. Serenity's Spa: Beauty Salon
#   ✓ 11. Makeup Girls: Dress up games
#   ✓ 12. Tira: Online Beauty Shopping
#   ✓ 13. Makeover Madness: Cook & Style
#   ✓ 14. CHARLOTTE TILBURY: EASY BEAUTY
#   ✓ 15. Skin Bliss: Skincare Routines
#   ✓ 16. Nykaa - Beauty Shopping App
#   ✓ 17. Makeup Girls - Games for kids
#   ✓ 18. Beauty Salon Games for Girls
#   ✓ 19. Purplle Online Beauty Shopping
#   ✓ 20. SODA - Natural Beauty Camera
#   ✓ 21. Beauty Salon: Spa & Nail Game
#   ✓ 22. Boozyshop
#   ✓ 23. BELLEMINT - Fashion and Beauty
#   ✓ 24. Skincare Routine: FeelinMySkin
#   ✓ 25. Standard Skin & Beauty
#   ✓ 26. Sally's Salon - Beauty Secrets
#   ✓ 27. B612 AI Photo&Video Editor
#   ✓ 28. My First Makeover
#   ✓ 29. Beauty Empire
#   ✓ 30. Wig Studio 1
#
# Searching: BOOKS_AND_REFERENCE
# Gagal search keyword BOOKS_AND_REFERENCE: 'NoneType' object is not subscriptable
#
# Searching: BUSINESS
#   ✓ 1. Meta Business Suite
#   ✓ 2. WhatsApp Business
#   ✓ 3. Yelp for Business
#   ✓ 4. Business Empire: RichMan
#   ✓ 5. Business in a Box
#   ✓ 6. QuickBooks Online Accounting
#   ✓ 7. Revolut Business
#   ✓ 8. PayPal Business
#   ✓ 9. Popl: Digital Business Card
#   ✓ 10. Amazon Business: B2B Shopping
#   ✓ 11. Selldone - Business OS
#   ✓ 12. Novo - Small Business Checking
#   ✓ 13. Booksy Biz: For Businesses
#   ✓ 14. Walmart Business: B2B Shopping
#   ✓ 15. Business Game
#   ✓ 16. Nav Business Financial Health
#   ✓ 17. Skype for Business for Android
#   ✓ 18. HoneyBook - Small Business CRM
#   ✓ 20. Square Point of Sale: Payment
#   ✓ 21. Business Texting with Salesmsg
#   ✓ 23. DoorDash - Business Manager
#   ✓ 24. Etsy Seller: Manage Your Shop
#   ✓ 25. Bizplanr- AI Business Planner
#   ✓ 26. Retail POS Billing & Inventory
#   ✓ 27. Mindbody Business
#
# Searching: COMICS
#   ✓ 1. GlobalComix: Comic Book Reader
#   ✓ 2. WEBTOON: Manga, Comics, Manhwa
#   ✓ 3. Tapas – Comics and Novels
#   ✓ 4. WebComics - Webtoon & Manga
#   ✓ 5. Marvel Unlimited
#   ✓ 6. Lezhin Comics - Daily Releases
#   ✓ 7. Tappytoon Manhwa & Novels
#   ✓ 8. Key Collector Comics
#   ✓ 9. CLZ Comics comic book database
#   ✓ 10. Pocket Toons: Comics & Webtoon
#   ✓ 11. Manta: Comics & Graphic Novels
#   ✓ 12. Shonen Jump Manga & Comics
#   ✓ 13. POCKET COMICS: Premium Webtoon
#   ✓ 14. Dashtoon: Comics & Manga
#   ✓ 15. WebNovel
#   ✓ 16. Toomics - Read Premium Comics
#   ✓ 17. 네이버 웹툰 - Naver Webtoon
#   ✓ 18. League of Comic Geeks
#   ✓ 19. CDisplayEx Comic Reader
#   ✓ 20. WeComics TH: Webtoon
#   ✓ 21. 리디 - 웹툰, 만화, 웹소설, 전자책 모두 여기에!
#   ✓ 22. INKR — Comics, Manga, Webtoons
#   ✓ 23. Bubble BD Comics Mangas
#   ✓ 24. Tinyview Comics
#   ✓ 25. Gurukula Stories Comics Audios
#   ✓ 26. 이만배 - 이걸? 만화로 배워!?
#   ✓ 27. 카카오페이지 KakaoPage
#   ✓ 28. izneo: Read Manga and Comics
#   ✓ 29. DELITOON DE - Manga & Comics
#   ✓ 30. Bonelli Digital Classic
#
# Searching: COMMUNICATION
#   ✓ 3. Discord - Talk, Play, Hang Out
#   ✓ 4. WhatsApp Messenger
#   ✓ 5. Google Chat
#   ✓ 6. Google Messages
#   ✓ 7. Messenger
#   ✓ 9. Signal Private Messenger
#   ✓ 10. JusTalk Kids - Safe Messenger
#   ✓ 12. LINE: Calls & Messages
#   ✓ 13. Messenger Kids – The Messaging
#   ✓ 14. Gmail
#   ✓ 15. Phone by Google
#   ✓ 16. Truecaller: Caller ID Blocker
#   ✓ 19. Microsoft Outlook
#   ✓ 20. Contacts
#   ✓ 21. Zangi Private Messenger
#   ✓ 22. Skype
#   ✓ 23. Rakuten Viber Messenger
#   ✓ 24. Zoom Workplace
#   ✓ 25. Yahoo Mail
#   ✓ 26. Text Me: Second Phone Number
#   ✓ 27. WeChat
#   ✓ 28. KakaoTalk : Messenger
#   ✓ 29. VK: music, video, messenger
#   ✓ 30. Google Fi Wireless
#   ✓ 31. Marco Polo - Video Messenger
#   ✓ 33. Text Free: Second Call Number
#   ✓ 34. Starlink
#   ✓ 35. Zalo
#   ✓ 36. Webex
#   ✓ 37. Botim - Video and Voice Call
#   ✓ 38. GroupMe
#   ✓ 39. Proton Mail: Encrypted Email
#   ✓ 40. Zello PTT Walkie Talkie
#   ✓ 41. CallApp: Caller ID & Block
#   ✓ 42. Samsung Email
#   ✓ 43. Eyecon Caller ID & Spam Block
#   ✓ 44. Smart
#   ✓ 45. MyJio: For Everything Jio
#   ✓ 46. My Verizon
#   ✓ 47. Xfinity
#   ✓ 48. Spike: AI Email & Team Chat
#   ✓ 49. Link Messenger
#   ✓ 50. Plus Messenger
#
# Searching: DATING
#   ✓ 5. Badoo Dating App: Meet & Date
#   ✓ 7. Hily Dating app: Meet & Date
#   ✓ 8. Feeld: Open-Minded Dating App
#   ✓ 9. Taimi - LGBTQ+ Dating and Chat
#   ✓ 10. Plenty of Fish Dating App
#   ✓ 11. MeetMe: Chat & Meet New People
#   ✓ 12. Kismia - Meet Singles Nearby
#   ✓ 13. happn: Dating, Chat & Meet
#   ✓ 14. Match Dating App : Chat & Meet
#   ✓ 15. Lovely – Meet and Date Locals
#   ✓ 16. Dating.com: Global Online Date
#   ✓ 17. eharmony dating & real love
#   ✓ 18. Chispa: Dating App for Latinos
#   ✓ 19. Jaumo Dating App: Flirt & Date
#   ✓ 20. HER Lesbian, bi & queer dating
#   ✓ 21. TanTan - Asian Dating App
#   ✓ 22. Turn Up: Music, Dating & Chat
#   ✓ 23. Coffee Meets Bagel: Dating App
#   ✓ 24. BLOOM, Meet Singles. Find Love
#   ✓ 25. Mamba Dating App: Make friends
#   ✓ 26. Dil Mil: South Asian Dating
#
# Searching: EDUCATION
#   ✓ 1. Prodigy Math: Kids Game
#   ✓ 2. Khan Academy Kids
#   ✓ 3. Duolingo: Language Lessons
#   ✓ 4. Coursera: Learn career skills
#   ✓ 6. Khan Academy
#   ✓ 7. Minecraft Education
#   ✓ 8. Starfall
#   ✓ 9. Google Classroom
#   ✓ 10. IXL
#   ✓ 11. ABCmouse – Kids Learning Games
#   ✓ 12. Memrise: Languages for life
#   ✓ 13. Quizlet: Study with Flashcards
#   ✓ 14. Ella School - English Learning
#   ✓ 15. ClassDojo
#   ✓ 16. ABCmouse 2: Kids Learning Game
#   ✓ 17. Gauth: AI Study Companion
#   ✓ 18. Alison: Online Education App
#   ✓ 19. Kahoot! Play & Create Quizzes
#   ✓ 20. Kids Games: For Toddlers 3-5
#   ✓ 21. PBS KIDS Games App
#   ✓ 22. Photomath
#   ✓ 23. Udemy - Online Courses
#   ✓ 24. Learn Coding/Programming: Mimo
#   ✓ 25. Moodle
#
# Searching: ENTERTAINMENT
#   ✓ 1. PolyBuzz: Chat with AI Friends
#   ✓ 3. Netflix
#   ✓ 5. Prime Video
#   ✓ 6. Chai: Chat AI Platform
#   ✓ 9. Talkie: Creative AI Community
#   ✓ 10. Xbox
#   ✓ 11. Character AI: Chat, Talk, Text
#   ✓ 13. YouTube Kids
#   ✓ 16. Max: Stream HBO, TV, & Movies
#   ✓ 18. Crunchyroll
#   ✓ 21. Google TV
#
# Searching: EVENTS
#   ✓ 1. Eventbrite App
#   ✓ 2. AllEvents - Discover Events
#   ✓ 3. Fever: Events & Tickets
#   ✓ 4. Cvent Events
#   ✓ 5. Ticketmaster－Buy, Sell Tickets
#   ✓ 6. Meetup: Social Events & Groups
#   ✓ 7. Eventeam - Events and fun
#   ✓ 8. Vivid Seats | Event Tickets
#   ✓ 9. StubHub - Live Event Tickets
#   ✓ 10. SeatGeek – Tickets to Events
#   ✓ 11. Event Planner: Birthday, Party
#   ✓ 12. AWS Events
#   ✓ 13. District: Movies Events Dining
#   ✓ 14. AXS Tickets
#   ✓ 15. BookMyShow | Movies & Events
#   ✓ 16. DICE: Live Shows
#   ✓ 17. Gametime - Last Minute Tickets
#   ✓ 18. MLB Ballpark
#   ✓ 19. TickPick - Live Event Tickets
#   ✓ 20. Bandsintown Concerts
#   ✓ 21. Gridaly: Event app
#   ✓ 22. Sympla: Ingressos para eventos
#   ✓ 23. Partiful: Fun Party Invites
#   ✓ 24. EventLive - Live Stream Events
#   ✓ 25. TIME&SPACE: Events Media
#   ✓ 26. Live Nation At The Concert
#   ✓ 27. Bortúra App
#   ✓ 28. EVENTIM DE: Tickets for Events
#   ✓ 29. EventSource.ca
#   ✓ 30. EG Leaders
#
# Searching: FINANCE
#   ✓ 1. Yahoo Finance: Stocks & News
#   ✓ 2. Google Wallet
#   ✓ 6. Robinhood - FinTech SuperApp
#   ✓ 7. BESTPLAY Play to earn & donate
#   ✓ 8. Nu
#   ✓ 9. Mercado Pago: cuenta digital
#   ✓ 11. Acorns: Invest For Your Future
#   ✓ 12. Webull: Investing & Trading
#   ✓ 14. Chase Mobile
#   ✓ 15. Paytm: Secure UPI Payments
#   ✓ 16. ELDIK
#   ✓ 17. DANA Indonesia Digital Wallet
#   ✓ 18. Revolut: Spend, Save, Trade
#   ✓ 19. Fidelity Investments
#   ✓ 20. Klarna | Shop now. Pay later.
#   ✓ 21. Venmo
#   ✓ 22. Capital One Mobile
#   ✓ 23. Trust: Crypto & Bitcoin Wallet
#   ✓ 24. Public – Stocks and Options
#   ✓ 25. easypaisa – a digital bank
#   ✓ 26. MetaMask - Crypto Wallet
#   ✓ 27. Bank of America Mobile Banking
#   ✓ 28. Coinbase: Buy BTC, ETH, SOL
#   ✓ 29. Wise: International Transfers
#
# Searching: FOOD_AND_DRINK
#   ✓ 1. Gopuff—Alcohol & Food Delivery
#   ✓ 2. DoorDash: Food, Grocery, More
#   ✓ 3. 7NOW: Food Delivery & Alcohol
#   ✓ 4. Eat and Drink
#   ✓ 5. Instacart: Get Food Delivery
#   ✓ 6. Dunkin’
#   ✓ 7. Uber Eats: Food Delivery
#   ✓ 8. Grubhub: Food Delivery
#   ✓ 9. Taco Bell Fast Food & Delivery
#   ✓ 10. UK Food & Drink Shows 2025
#   ✓ 11. Yuka - Food & Cosmetic Scanner
#   ✓ 12. Domino's Pizza USA
#   ✓ 13. HelloFresh: Meal Kit Delivery
#   ✓ 14. Cooklist: Pantry & Cooking App
#   ✓ 15. Eatventure
#   ✓ 16. Fig: Food Scanner & Discovery
#   ✓ 17. Foodvisor - Calorie Counter
#   ✓ 18. Little Caesars
#   ✓ 19. Weee! Asian Grocery Delivery
#   ✓ 20. Wendy’s
#
# Searching: HEALTH_AND_FITNESS
#   ✓ 1. Fitbit
#   ✓ 2. Bodylura: Fitness & Nutrition
#   ✓ 3. Health & Fitness Tracker
#   ✓ 4. Google Fit: Activity Tracking
#   ✓ 5. Samsung Health
#   ✓ 6. Weight Loss Walking: WalkFit
#   ✓ 7. LiveWell by Zurich
#   ✓ 8. Fitbod: Workout & Gym Planner
#   ✓ 9. MyFitnessPal: Calorie Counter
#   ✓ 10. Calorie Counter by Cronometer
#   ✓ 11. Peloton - Fitness & Workouts
#   ✓ 12. FITIV Pulse Heart Rate Monitor
#   ✓ 13. Headspace: Meditation & Health
#   ✓ 14. BODi Fitness, Workouts, & Gym
#   ✓ 15. fit52: Fitness & Workout Plans
#   ✓ 16. Strava: Run, Bike, Hike
#   ✓ 17. FitOn Workouts & Fitness Plans
#   ✓ 18. Cardi Health: Heart Monitoring
#   ✓ 19. BetterMe: Health Coaching
#   ✓ 20. WeightWatchers Program
#   ✓ 21. Health Connect
#   ✓ 22. The Body Coach: Fitness Plans
#   ✓ 23. fitbite - AI Fitness Coach
#   ✓ 24. Cardiogram: BP & Heart Rate
#   ✓ 25. Seven - 7 Minute Workout
#   ✓ 26. Fasting App & Calorie Counter
#   ✓ 27. Home Workout - No Equipment
#   ✓ 28. Fit Path: All-in-One Coaching
#   ✓ 29. VeryFit
#   ✓ 30. Step Tracker - Pedometer
#
# Searching: HOUSE_AND_HOME
#   ✓ 1. Home Street - Dream House Sim
#   ✓ 2. Realtor.com Real Estate & Rent
#   ✓ 3. Zillow: Homes For Sale & Rent
#   ✓ 5. Homescapes
#   ✓ 6. Google Home
#   ✓ 7. House Flipper: Home Design
#   ✓ 8. The Home Depot
#   ✓ 9. Home Design Makeover
#   ✓ 10. Trulia: Homes For Sale & Rent
#   ✓ 11. Homes.com Real Estate Search
#   ✓ 12. Property Brothers Home Design
#   ✓ 13. Rent. Apartments & Homes
#   ✓ 14. Redfin Houses for Sale & Rent
#   ✓ 15. Live Home 3D: House Design
#   ✓ 16. My Estate Quest - House Design
#   ✓ 17. Matchington Mansion
#   ✓ 18. Sweet Home : Design & Blast
#   ✓ 20. TP-Link Tapo
#   ✓ 21. House Designer : Fix & Flip
#   ✓ 22. Adorable Home
#   ✓ 23. Home Mansion: Design & Match
#   ✓ 24. House Flip
#   ✓ 25. Home Assistant
#   ✓ 26. Xiaomi Home
#   ✓ 27. Decor Life - Home Design Game
#   ✓ 28. Mergedom: Home Design & Merge
#   ✓ 29. Interio: House, home design 3D
#   ✓ 30. Design My Home: Makeover Games
#
# Searching: LIBRARIES_AND_DEMO
#   ✓ 1. Libraries for developers
#   ✓ 2. Google Play Books & Audiobooks
#   ✓ 3. Google Gemini
#   ✓ 5. Audible: Audio Entertainment
#   ✓ 7. JW Library
#   ✓ 8. Amazon Music: Songs & Podcasts
#   ✓ 9. Amazon Alexa
#   ✓ 11. Everand: Ebooks and audiobooks
#   ✓ 12. iHeart: Music, Radio, Podcasts
#   ✓ 14. Gospel Library
#   ✓ 15. Libby, the Library App
#   ✓ 16. Ultimate Guitar: Chords & Tabs
#   ✓ 17. Poe - Fast AI Chat
#   ✓ 18. Agoda: Cheap Flights & Hotels
#   ✓ 19. CloudLibrary
#   ✓ 20. hoopla Digital
#   ✓ 21. Wikipedia
#   ✓ 22. Claude by Anthropic
#   ✓ 23. ePlatform Digital Libraries
#   ✓ 24. Galatea: Books & Audiobooks
#   ✓ 25. Kobo | eBooks & Audiobooks
#   ✓ 26. Strategy Library
#   ✓ 27. AI Dungeon
#
# Searching: LIFESTYLE
#   ✓ 1. Me+ Lifestyle Routine
#   ✓ 2. Fabulous Daily Routine Planner
#   ✓ 3. Fresh Tri: Habits & Mindset
#   ✓ 4. My Lifestyle iQ
#   ✓ 5. Lemon8 - Lifestyle Community
#   ✓ 7. Finch: Self-Care Pet
#   ✓ 8. Lifestyle2.0
#   ✓ 9. Remente: Self Care, Wellbeing
#   ✓ 10. Love Nikki-Dress UP Queen
#   ✓ 11. Simple Lifestyle
#   ✓ 12. Life360: Stay Connected & Safe
#   ✓ 13. Life Makeover
#   ✓ 14. Gratitude: Self-Care Journal
#   ✓ 15. Lifesum: AI Calorie Tracker
#   ✓ 19. SilverLeaf Lifestyle
#   ✓ 21. Uber - Request a ride
#   ✓ 22. Gacha Life
#   ✓ 24. Calorie Counter by Lose It!
#   ✓ 25. EA SPORTS FC™ Mobile Soccer
#   ✓ 26. Pakuwon Lifestyle
#   ✓ 27. Hollywood Story®: Fashion Star
#   ✓ 28. SuitU: Fashion Avatar Dress Up
#   ✓ 30. Body SDS Lifestyle
#
# Searching: MAPS_AND_NAVIGATION
#   ✓ 1. HERE WeGo: Maps & Navigation
#   ✓ 3. what3words: Navigation & Maps
#   ✓ 4. Waze Navigation & Live Traffic
#   ✓ 5. Google Go
#   ✓ 6. Yandex Maps and Navigator
#   ✓ 7. Google Earth
#   ✓ 8. OsmAnd — Maps & GPS Offline
#   ✓ 9. Yandex Navigator
#   ✓ 10. AllTrails: Hike, Bike & Run
#   ✓ 11. NAVER Map, Navigation
#   ✓ 12. Mapy.com: maps & navigation
#   ✓ 13. Moovit: Your Transit Tracker
#   ✓ 14. komoot - hike, bike & run
#   ✓ 15. Citymapper
#   ✓ 16. Sygic GPS Navigation & Maps
#   ✓ 17. MAPS.ME: Offline maps GPS Nav
#   ✓ 18. Hammer: Truck GPS & Maps
#   ✓ 19. TomTom AmiGO - GPS Navigation
#   ✓ 20. Gaia GPS: Offroad Hiking Maps
#   ✓ 21. Petal Maps – GPS & Navigation
#   ✓ 22. Magic Earth Navigation & Maps
#   ✓ 23. Wikiloc - Trails of the World
#   ✓ 24. Avenza Maps: Offline Mapping
#   ✓ 25. نشان | نقشه و مسیریاب Neshan
#   ✓ 26. Geo Tracker - GPS tracker
#   ✓ 27. Circuit Route Planner
#   ✓ 28. Map My Walk: Walking Tracker
#   ✓ 29. Trucker Path: Truck GPS & Fuel
#   ✓ 30. Dott
#
# Searching: MEDICAL
#   ✓ 1. MyChart
#   ✓ 2. Flo Period & Pregnancy Tracker
#   ✓ 3. Full Code Medical Simulation
#   ✓ 4. WebMD: Symptom Checker
#   ✓ 5. Walgreens
#   ✓ 6. Teladoc Health
#   ✓ 7. Medicine Delivery - PlatinumRx
#   ✓ 8. Ada – check your health
#   ✓ 9. Rosa
#   ✓ 10. CVS Health
#   ✓ 11. Period Calendar Period Tracker
#   ✓ 12. healow
#   ✓ 13. VA: Health and Benefits
#   ✓ 14. Pocket Prep Medical 2025
#   ✓ 15. Med & Pill Reminder MyTherapy
#   ✓ 16. Medical Terminology Learning Q
#   ✓ 17. TATA 1mg Online Healthcare App
#   ✓ 18. Health Diary by MedM
#   ✓ 19. K Health | 24/7 Virtual Care
#   ✓ 20. Impulse - Brain Training Games
#   ✓ 21. Clue Cycle & Period Tracker
#   ✓ 22. Dexcom G7
#   ✓ 23. Osmosis Med Videos & Notes
#   ✓ 24. Teach Me Anatomy
#   ✓ 25. myPhonak
#   ✓ 26. Kaiser Permanente
#   ✓ 27. Pillo: Pill Reminder & Tracker
#   ✓ 28. Sydney Health
#   ✓ 29. Anatomy Learning - 3D Anatomy
#   ✓ 30. MyID – Medical ID Profile
#
# Searching: MUSIC_AND_AUDIO
#   ✓ 4. BandLab – Music Making Studio
#   ✓ 6. Yandex Music, Books & Podcasts
#   ✓ 7. Shazam: Find Music & Concerts
#   ✓ 11. Music Player - MP3 Player
#   ✓ 12. Lark Player:Music Player & MP3
#   ✓ 13. StarMaker: Sing Karaoke Songs
#   ✓ 15. Deezer: Music & Podcast Player
#   ✓ 16. TIDAL Music: HiFi sound
#   ✓ 18. GuitarTuna: Tune & Play Guitar
#   ✓ 19. Pi Music Player: Offline Music
#   ✓ 20. Samsung Music
#   ✓ 21. Music Player & MP3 Player
#   ✓ 22. Yousician: Learn Guitar & Bass
#   ✓ 23. Moises: The Musician's AI App
#   ✓ 25. Suno - AI Music
#   ✓ 26. TuneIn Radio: Music & Sports
#   ✓ 27. Pocket Casts - Podcast App
#   ✓ 28. TREBEL: Music, MP3 & Podcasts
#   ✓ 29. JioSaavn - Music & Podcasts
#   ✓ 30. Mi Music
#   ✓ 31. Smule: Karaoke, Sing & Record
#   ✓ 32. Podcast Addict: Podcast player
#   ✓ 33. Voloco: Auto Vocal Tune Studio
#   ✓ 34. Boomplay: Music & Live Stream
#   ✓ 35. Music Player & MP3 - DDMusic
#   ✓ 36. Poweramp: Music Player (Trial)
#   ✓ 37. Voice Recorder
#   ✓ 38. Music player
#   ✓ 39. Recorder
#   ✓ 40. Musicolet Music Player
#   ✓ 41. Simply Piano: Learn Piano Fast
#   ✓ 42. Easy Voice Recorder
#   ✓ 43. Offline Music Player: Play MP3
#   ✓ 44. Music Player
#   ✓ 45. Spotify for Creators
#   ✓ 46. Music Player - Audify Player
#   ✓ 47. Podcast Player - Castbox
#   ✓ 48. Podcast Player App - Podbean
#   ✓ 49. Podcast Player
#   ✓ 50. Tuner & Metronome
#
# Searching: NEWS_AND_MAGAZINES
#   ✓ 1. Google News - Daily Headlines
#   ✓ 2. Opera News: breaking & local
#   ✓ 3. Dailyhunt - News & Magazines
#   ✓ 4. SmartNews: News That Matters
#   ✓ 5. Substack
#   ✓ 6. The Guardian - News & Sport
#   ✓ 7. CNN: Breaking US & World News
#   ✓ 8. MSN
#   ✓ 9. BBC: World News & Stories
#   ✓ 10. Flipboard:Your Social Magazine
#   ✓ 11. AP News: World & Local
#   ✓ 12. Ground News
#   ✓ 13. Medium
#   ✓ 14. Hindi News by Dainik Bhaskar
#   ✓ 15. PressReader: News & Magazines
#
# Searching: PARENTING
#   ✓ 1. Google Family Link
#   ✓ 2. Parents
#   ✓ 3. The Happy Child Parenting App
#   ✓ 4. Good Inside: Parenting
#   ✓ 5. TalkingParents: Co-Parent App
#   ✓ 6. Huckleberry: Baby & Child
#   ✓ 7. AppClose: Co-Parent Essentials
#   ✓ 8. OurFamilyWizard Co-Parent App
#   ✓ 9. Breastfeeding & Baby Tracker
#   ✓ 10. AirDroid Parental Control
#   ✓ 11. Pregnancy App & Baby Tracker
#   ✓ 12. Pregnancy + | Tracker App
#   ✓ 13. Findmykids: Kids GPS Tracker
#   ✓ 14. Understood: Support ADHD Kids
#   ✓ 15. Nanit
#   ✓ 16. Owlet Dream
#   ✓ 17. Parenthood: Happy Parenting
#   ✓ 18. In Love while Parenting
#   ✓ 19. Parenting Guide from Lasting
#   ✓ 20. Little Love Parenting
#   ✓ 21. Pregnancy Tracker & Baby App
#   ✓ 22. FlashGet Kids:parental control
#   ✓ 23. Family360 - GPS Live Locator
#   ✓ 24. Baby Leap: Milestone Tracker
#   ✓ 25. HubbleClub By Hubble Connected
#   ✓ 26. Motherhood: Parenting SuperApp
#   ✓ 27. Nara - Baby & Mom Tracker
#   ✓ 28. Babylist Baby Registry
#   ✓ 29. EasyPeasy - Parenting Tips
#   ✓ 30. Parentool - Parenting app
#
# Searching: PERSONALIZATION
#   ✓ 1. Google Photos
#   ✓ 2. Gboard - the Google Keyboard
#   ✓ 3. Wallpapers
#   ✓ 4. Microsoft Launcher
#   ✓ 5. Zedge™ Wallpapers & Ringtones
#   ✓ 6. Microsoft SwiftKey AI Keyboard
#   ✓ 7. Smart Launcher 6 ‧ Home Screen
#   ✓ 8. Nova Launcher
#   ✓ 9. Widgetable: Besties & Couples
#   ✓ 10. Samsung Global Goals
#   ✓ 11. Locket Widget
#   ✓ 12. Square Home
#   ✓ 13. Facemoji AI Emoji Keyboard
#   ✓ 14. Niagara Launcher ‧ Home Screen
#   ✓ 15. TickTock-TikTok Live Wallpaper
#   ✓ 16. XOS Launcher -Cool Stylish
#   ✓ 17. Shimeji: Screen Buddy App
#   ✓ 18. Moto Widget
#   ✓ 19. HiOS Launcher - Fast
#   ✓ 20. Fonts Art: Cute Keyboard Font
#   ✓ 21. Moto
#   ✓ 22. POCO Launcher 2.0 - Customize,
#   ✓ 23. Moto Interactive Wallpaper
#   ✓ 24. Magazine Lockscreen XOS
#   ✓ 25. Yandex Keyboard
#   ✓ 26. Icon Pack Studio
#   ✓ 27. Magazine Lockscreen HiOS
#   ✓ 28. Shelf
#   ✓ 29. Backdrops - Wallpapers
#   ✓ 30. تمام لوحة المفاتيح العربية
#
# Searching: PHOTOGRAPHY
#   ✓ 2. Gallery
#   ✓ 3. Photoshop Express Photo Editor
#   ✓ 5. Picsart AI Photo Editor, Video
#   ✓ 6. Unscripted Photography Posing
#   ✓ 7. Lightroom Photo & Video Editor
#   ✓ 8. Snapseed
#   ✓ 9. VSCO: Photo & Video Editor
#   ✓ 10. PULSEpx - Photography
#   ✓ 11. EyeEm - Sell Your Photos
#   ✓ 12. Remini - AI Photo Enhancer
#   ✓ 13. Photoroom AI Photo Editor
#   ✓ 14. 500px-Photo Sharing Community
#   ✓ 15. FaceApp: Perfect Face Editor
#   ✓ 17. Photo Studio PRO
#   ✓ 18. GuruShots: Photo Game
#   ✓ 21. Photo Lab Picture Editor & Art
#   ✓ 22. Amazon Photos: Photo & Video
#   ✓ 23. AI Photo Editor - Polish
#   ✓ 24. Photo Studio: pictures editor!
#   ✓ 25. PhotoDirector: AI Photo Editor
#   ✓ 26. Golden Hour: Sunset & Sunrise
#   ✓ 28. Meitu
#   ✓ 29. Pixel Camera
#   ✓ 30. Photo Editor - Lumii
#   ✓ 31. PhotoApp - AI Photo Enhancer
#   ✓ 32. ToonMe photo cartoon maker
#   ✓ 33. Collage Maker | Photo Editor
#   ✓ 34. Hypic - Photo Editor & AI Art
#   ✓ 35. Bazaart AI Photo Editor Design
#   ✓ 37. Gallery- Photo Gallery & Album
#   ✓ 38. Fotor - AI Photo Editor
#   ✓ 39. PicCollage: Photo Grid Editor
#   ✓ 40. SNOW - AI Profile
#   ✓ 41. Remove Objects - Photo Editor
#   ✓ 43. Private Photo Vault - Keepsafe
#   ✓ 44. Background Eraser Photo Editor
#   ✓ 45. FreePrints
#   ✓ 46. Photify AI: AI Photo Generator
#   ✓ 47. UpFoto - AI Photo Enhancer
#   ✓ 48. Face & Body Editor - AI Photo
#   ✓ 49. Facetune: Hair, Photo Editor
#   ✓ 50. OldRoll - Vintage Film Camera
#
# Searching: PRODUCTIVITY
#   ✓ 3. Google Drive
#   ✓ 4. Forest: Focus for Productivity
#   ✓ 5. Google Calendar
#   ✓ 6. Todoist: Planner & Calendar
#   ✓ 7. Boosted Time Tracker
#   ✓ 8. Google Tasks
#   ✓ 10. Microsoft 365 Copilot
#   ✓ 11. Grok - AI Assistant
#   ✓ 12. Google Docs
#   ✓ 13. Focus To-Do: Pomodoro & Tasks
#   ✓ 15. Microsoft Word: Edit Documents
#   ✓ 16. Google Keep - Notes and lists
#   ✓ 17. Habitica: Gamify Your Tasks
#   ✓ 18. Google Sheets
#   ✓ 19. Google Slides
#   ✓ 20. Microsoft Excel: Spreadsheets
#   ✓ 21. Perplexity - Ask Anything
#   ✓ 22. Samsung Notes
#   ✓ 23. CamScanner- scanner, PDF maker
#   ✓ 24. Notion: Notes, Tasks, AI
#   ✓ 25. WPS Office-PDF,Word,Sheet,PPT
#   ✓ 26. Microsoft PowerPoint
#   ✓ 27. Dropbox: Secure Cloud Storage
#   ✓ 28. Digital Wellbeing
#   ✓ 29. Microsoft OneNote: Save Notes
#   ✓ 30. ​​Microsoft Copilot
#   ✓ 31. ADP Mobile Solutions
#
# Searching: SHOPPING
#   ✓ 1. Amazon Shopping
#   ✓ 3. Temu: Shop Like a Billionaire
#   ✓ 4. SHEIN-Shopping Online
#   ✓ 5. eBay online shopping & selling
#   ✓ 6. Target
#   ✓ 7. Flipkart Online Shopping App
#   ✓ 8. AliExpress - Shopping App
#   ✓ 9. Etsy: A Special Marketplace
#   ✓ 10. Wish: Shop and Save
#   ✓ 11. Myntra - Fashion Shopping App
#   ✓ 12. Fashion Nova: Trendy Shopping
#   ✓ 13. Best Buy: Shop tech deals
#   ✓ 14. Mercado Libre: Compras online
#   ✓ 15. Alibaba.com - B2B marketplace
#   ✓ 16. Meesho: Online Shopping App
#   ✓ 17. Poshmark - Sell & Shop Online
#   ✓ 18. Lazada 5.5 | Super Saver
#   ✓ 19. Kohl's - Shopping & More
#   ✓ 20. Shop: All your favorite brands
#   ✓ 21. Old Navy: Fashion at a Value!
#   ✓ 22. Flipp: Shop Grocery Deals
#   ✓ 23. Capital One Shopping
#   ✓ 24. Nike: Shoes, Apparel & Stories
#   ✓ 25. Tokopedia Guncang 5.5
#
# Searching: SOCIAL
#   ✓ 3. TikTok
#   ✓ 7. Truth Social
#   ✓ 10. Bluesky
#   ✓ 11. Facebook Lite
#   ✓ 13. Scoopz: Real Life, Real Video
#   ✓ 15. OK: Social Network
#   ✓ 17. Twitch: Live Streaming
#   ✓ 18. ZEPETO: Avatar, Connect & Live
#   ✓ 19. Tumblr—Fandom, Art, Chaos
#   ✓ 21. Fanbase
#   ✓ 22. Plato: Fun Multiplayer Games
#
# Searching: SPORTS
#   ✓ 1. Yahoo Sports: Scores & News
#   ✓ 2. theScore: Sports News & Scores
#   ✓ 3. ESPN
#   ✓ 4. FOX Sports: Watch Live Games
#   ✓ 5. Retro Bowl
#   ✓ 7. Sofascore: Live Sports Scores
#   ✓ 8. MLB
#   ✓ 9. LiveScore: Live Sports Scores
#   ✓ 10. NBA: Live Games & Scores
#   ✓ 11. ESPN Fantasy Sports
#   ✓ 12. Madden NFL 25 Mobile Football
#   ✓ 13. NFL Rivals - Football Game
#   ✓ 14. Stadium Live - Predict Sports
#   ✓ 15. CBS Sports App: Scores & News
#   ✓ 16. The Athletic: Sports News
#   ✓ 17. Yahoo Fantasy Football, Sports
#   ✓ 18. NBA LIVE Mobile Basketball
#   ✓ 19. FotMob - Soccer Live Scores
#   ✓ 20. NCAA March Madness Live
#   ✓ 21. NBC Sports
#   ✓ 22. NBA Infinite - PvP Basketball
#   ✓ 23. MLB 9 Innings 25
#   ✓ 24. The Program: College Football
#   ✓ 25. 365Scores: Live Scores & News
#   ✓ 26. Cricbuzz - Live Cricket Scores
#   ✓ 27. BASEBALL 9
#   ✓ 28. Football Head Coach 25 NFL PA
#   ✓ 29. Retro Bowl College
#   ✓ 30. NBA 2K25 MyTEAM
#
# Searching: TOOLS
#   ✓ 1. Member Tools
#   ✓ 3. Samsung Internet Browser
#   ✓ 4. Files by Google
#   ✓ 5. Google
#   ✓ 6. Google Authenticator
#   ✓ 7. Google Chrome
#   ✓ 8. Google Translate
#   ✓ 10. Clock
#   ✓ 13. Fing - Network Tools
#   ✓ 14. Microsoft OneDrive
#   ✓ 15. Microsoft Edge: AI browser
#   ✓ 16. Opera: Private Web Browser
#   ✓ 17. Google Find My Device
#   ✓ 18. Brave Private Web Browser, VPN
#   ✓ 20. Firefox Fast & Private Browser
#   ✓ 22. DuckDuckGo Browser, Search, AI
#   ✓ 23. Opera Mini: Fast Web Browser
#   ✓ 25. SHAREit: Transfer, Share Files
#   ✓ 28. Microsoft Authenticator
#   ✓ 29. Android Accessibility Suite
#   ✓ 30. The Roku App (Official)
#
# Searching: TRAVEL_AND_LOCAL
#   ✓ 1. Skyscanner Flights Hotels Cars
#   ✓ 2. redBus Book Bus, Train Tickets
#   ✓ 3. Trainline: Train travel Europe
#   ✓ 4. MakeMyTrip - Flights & Hotels
#   ✓ 5. Railroad Empire: Train Game
#   ✓ 6. Real Cricket™ 20
#   ✓ 7. Train Station 2: Rail Tycoon
#   ✓ 8. Amtrak
#   ✓ 9. Tiny Rails - Train Tycoon 2025
#   ✓ 10. Eurostar Trains
#   ✓ 11. Ticket to Ride®
#   ✓ 13. Wego - Flights, Hotels, Travel
#   ✓ 14. Omio: Book Train, Bus, Flights
#   ✓ 15. Trip.com: Book Flights, Hotels
#   ✓ 16. MTA TrainTime
#   ✓ 17. SNCF Connect: Trains & routes
#   ✓ 18. ixigo Trains: Ticket Booking
#   ✓ 19. Goibibo: Hotel, Flight & Train
#   ✓ 21. ixigo: Flight & Hotel Booking
#   ✓ 22. ConfirmTkt: Train Booking App
#   ✓ 23. Cleartrip Hotels, Flights, Bus
#   ✓ 24. EaseMyTrip Flight, Hotel, Bus
#   ✓ 25. Yatra - Flights, Hotels, Bus
#   ✓ 26. AbhiBus Bus Ticket Booking App
#   ✓ 27. MyTransit NYC Subway & Bus MTA
#   ✓ 28. IndiGo Flight Booking App
#   ✓ 29. DB Navigator
#   ✓ 30. Île-de-France Mobilités
#
# Searching: VIDEO_PLAYERS
#   ✓ 1. Video Player All Format
#   ✓ 2. KMPlayer - All Video Player
#   ✓ 3. VLC for Android
#   ✓ 4. Video Player All Format
#   ✓ 5. Video Player for Android
#   ✓ 6. MX Player
#   ✓ 7. Video Player All Format
#   ✓ 8. NOVA Video Player
#   ✓ 9. Video Player - OPlayer
#   ✓ 10. SPlayer - Fast Video Player
#   ✓ 11. Video Player All Format
#   ✓ 12. Video Player - OPlayer Lite
#   ✓ 13. Visha-Video Player All Formats
#   ✓ 14. Video Player KMP
#
# Searching: WEATHER
#   ✓ 2. AccuWeather: Weather Radar
#   ✓ 3. Live Weather: Weather Forecast
#   ✓ 4. Weather Radar - Meteored News
#   ✓ 5. Weather data & microclimate :
#   ✓ 6. 1Weather Forecasts & Radar
#   ✓ 7. Yahoo Weather
#   ✓ 8. Local Weather：Weather Forecast
#   ✓ 9. Weather & Widget - Weawow
#   ✓ 10. Today Weather:Data by NOAA/NWS
#   ✓ 11. Windy.com - Weather Forecast
#   ✓ 12. Weather & Radar - Storm radar
#   ✓ 13. Weather Radar by WeatherBug
#   ✓ 14. Weather
#   ✓ 15. Weather - By Xiaomi
#   ✓ 16. Windy.app - Enhanced forecast
#   ✓ 17. MarcoPolo Weather
#   ✓ 18. Weather - Meteored Pro News
#   ✓ 19. MyRadar Weather Radar
#   ✓ 20. Weather
#   ✓ 21. Ventusky: Weather & Live Radar
#   ✓ 22. Yandex Weather & Rain Radar
#   ✓ 23. Yr
#   ✓ 24. Weather & Radar USA - Pro
#   ✓ 25. Weather: Live radar & widgets
#   ✓ 26. Local Weather Forecast - Radar
#   ✓ 27. RadarScope
#   ✓ 28. weather24: Forecast & Radar
#   ✓ 29. Rain Alarm
#   ✓ 30. RadarOmega
#
# Searching: GAME
#   ✓ 3. Mob Control
#   ✓ 4. Roblox
#   ✓ 5. Fruit Ninja®
#   ✓ 6. Sonic Dash Endless Runner Game
#   ✓ 7. Subway Surfers
#   ✓ 10. Asphalt 8 - Car Racing Game
#   ✓ 11. Disney Magic Kingdoms
#   ✓ 13. 8 Ball Pool
#   ✓ 14. Among Us
#   ✓ 15. Stumble Guys
#   ✓ 18. Plants vs. Zombies™
#   ✓ 19. Genshin Impact
#   ✓ 20. Hungry Shark Evolution
#   ✓ 21. Offline Games - No Wifi Games
#   ✓ 22. Hill Climb Racing 2
#   ✓ 24. Need for Speed™ No Limits
#   ✓ 26. Family Island™ — Farming game
#   ✓ 27. Harry Potter: Hogwarts Mystery
#   ✓ 29. Minion Rush: Running Game
#
# Searching: FAMILY
#   ✓ 2. Family Life
#   ✓ 3. Microsoft Family Safety
#   ✓ 4. FamilyWall: Family Organizer
#   ✓ 5. My Town Home: Family Playhouse
#   ✓ 6. Cozi Family Organizer
#   ✓ 8. Virtual Families 3
#   ✓ 9. Virtual Families 2
#   ✓ 10. Pocket Family Dreams: My Home
#   ✓ 11. FamilySearch: Family Tree App
#   ✓ 12. Family Space
#   ✓ 13. Family Diary: Mother Simulator
#   ✓ 14. Match Family: Triple Match 3D
#   ✓ 18. Jam Family Calendar
#   ✓ 19. The Godfather: Family Dynasty
#   ✓ 20. Family Rewards: Habit & Chores
#   ✓ 21. Sweet Home Stories
#   ✓ 22. Family Guy Freakin Mobile Game
#   ✓ 23. Family Tree! - Logic Puzzles
#   ✓ 24. Family Farm Adventure
#   ✓ 25. Merge Family: House merge game
#   ✓ 26. Norton Family Parental Control
#   ✓ 27. FamiLami - Habit Tracker
#   ✓ 29. Verizon Family
#   ✓ 30. Connected Family
#
# Searching: GAME_ACTION
#   ✓ 4. Brawl Stars
#   ✓ 5. World War Heroes — WW2 PvP FPS
#   ✓ 6. Into the Dead 2
#   ✓ 9. Marvel Contest of Champions
#   ✓ 11. Squad Busters
#   ✓ 15. Blood Strike - FPS for all
#   ✓ 17. Injustice 2
#   ✓ 18. Standoff 2
#   ✓ 19. Mr Autofire
#   ✓ 21. Mortal Kombat
#   ✓ 22. Arena Breakout: Realistic FPS
#   ✓ 25. Swordigo
#   ✓ 27. Talking Tom Gold Run
#   ✓ 28. Dan the Man: Action Platformer
#   ✓ 29. Shadow Fight 3 - RPG fighting
#   ✓ 30. Talking Tom Hero Dash
#
# Searching: GAME_ADVENTURE
#   ✓ 2. Top Heroes: Kingdom Saga
#   ✓ 3. Pikmin Bloom
#   ✓ 4. Manor Matters
#   ✓ 6. Chapters: Interactive Stories
#   ✓ 7. Infinity Nikki
#   ✓ 8. Criminal Case
#   ✓ 9. Unsolved: Hidden Mystery Games
#   ✓ 10. Tears of Themis
#   ✓ 11. Seekers Notes: Hidden Objects
#   ✓ 12. Mystery Matters
#   ✓ 14. Sherlock・Hidden Object Mystery
#   ✓ 15. Adventure Escape Mysteries
#   ✓ 16. Tokyo Debunker
#   ✓ 17. LEGO® DUPLO® Marvel
#   ✓ 18. An Elmwood Trail - Crime Story
#   ✓ 19. Robbery Bob 2: Double Trouble
#   ✓ 20. Island Hoppers: Farm Adventure
#   ✓ 21. Dorian: Interactive Dramas Hub
#   ✓ 22. Hidden Escape Mysteries
#   ✓ 23. Diggy's Adventure: Escape Game
#   ✓ 24. Star Equestrian - Horse Ranch
#   ✓ 25. Obey Me! Anime Otome Sim Game
#   ✓ 26. Hidden Objects: Coastal Hill
#   ✓ 27. Duskwood - Detective Story
#   ✓ 28. My Stories: Choose Chapters
#   ✓ 29. Pearl's Peril - Hidden Objects
#   ✓ 30. Ravenhill: Find Hidden Objects
#   ✓ 31. Ice Age Adventures
#   ✓ 32. Lost Lands 2
#   ✓ 33. Legendary Tales 2
#   ✓ 34. Mystery Files: Hidden Objects
#   ✓ 35. Lost Lands 3
#   ✓ 36. Lost Lands 1
#   ✓ 37. The Walking Dead: Season One
#   ✓ 38. Lost Lands 7
#   ✓ 39. Darkness and Flame 4
#   ✓ 40. New York Mysteries 1
#   ✓ 41. Mystic Messenger
#   ✓ 42. Mystery Manor: hidden objects
#   ✓ 43. Lost Lands 8
#   ✓ 44. Puzzle Adventure: Mystery Game
#   ✓ 45. Deadly Puzzles: Toymaker
#   ✓ 46. Lost Lands 4
#   ✓ 47. Legendary Tales 1
#   ✓ 48. Peek a Phone - Detective Game
#   ✓ 49. Lost Lands 9
#   ✓ 50. Adventure Academy
#
# Searching: GAME_ARCADE
#   ✓ 7. Jetpack Joyride
#   ✓ 8. SpongeBob: Krusty Cook-Off
#   ✓ 9. PAC-MAN
#   ✓ 10. Asphalt Legends Unite
#   ✓ 15. Tower War - Tactical Conquest
#   ✓ 16. Cooking Madness: A Chef's Game
#   ✓ 17. Geometry Dash Lite
#   ✓ 18. HATSUNE MIKU: COLORFUL STAGE!
#   ✓ 19. Head Ball 2 - Online Soccer
#   ✓ 20. Domino Dreams™
#   ✓ 21. Pocket Champs: 3D Racing Games
#   ✓ 22. Temple Run
#   ✓ 23. Beatstar - Touch Your Music
#   ✓ 24. CookieRun: OvenBreak
#   ✓ 26. My Cooking: Restaurant Game
#   ✓ 27. Airplane Chefs - Cooking Game
#   ✓ 28. Red Ball 4
#   ✓ 29. Basketball Arena: Sport Game
#   ✓ 30. Piano Fire: Edm Music & Piano
#
# Searching: GAME_BOARD
#   ✓ 1. Board Kings: Board Dice Games
#   ✓ 2. MONOPOLY GO!
#   ✓ 3. RISK: Global Domination
#   ✓ 4. Chess - Play and Learn
#   ✓ 5. MONOPOLY Solitaire: Card Games
#   ✓ 6. Ludo King®
#   ✓ 8. Yalla Ludo - Ludo&Domino
#   ✓ 9. Dice Dreams™️
#   ✓ 10. Parchisi STAR Online
#   ✓ 11. Jawaker Hand, Trix & Pool
#   ✓ 12. Ludo Club - Dice & Board Game
#   ✓ 13. Dune: Imperium Digital
#   ✓ 14. Lama Ludo-Ludo&Chatroom
#   ✓ 15. Game of Dice: Board&Card&Anime
#   ✓ 17. 1 2 3 4 Player Games - Offline
#   ✓ 18. YAHTZEE With Buddies Dice Game
#   ✓ 19. Ludo STAR: Online Dice Game
#   ✓ 20. Clue: Classic Edition
#   ✓ 21. Backgammon - Lord of the Board
#   ✓ 22. 2 Player games : the Challenge
#   ✓ 23. Dixit World
#   ✓ 24. Yatzy - Fun Classic Dice Game
#   ✓ 25. Chess - Offline Board Game
#   ✓ 26. Spirit Island
#   ✓ 27. Board Heroes: Dice RPG Game
#   ✓ 29. Yalla Parchis
#   ✓ 30. 101 Okey Plus Rummy Board Game
#
# Searching: GAME_CARD
#   ✓ 1. Hearthstone
#   ✓ 2. Pokémon TCG Pocket - Card Game
#   ✓ 3. Magic: The Gathering Arena
#   ✓ 5. UNO!™
#   ✓ 6. Legends of Runeterra
#   ✓ 7. MARVEL SNAP
#   ✓ 8. FreeCell Solitaire: Card Games
#   ✓ 9. Black Deck - Card Battle CCG
#   ✓ 10. Cards, Universe & Everything
#   ✓ 11. Disney Solitaire
#   ✓ 12. Candy Crush Solitaire
#   ✓ 13. Castle Solitaire: Card Game
#   ✓ 14. Yu-Gi-Oh! Duel Links
#   ✓ 15. Solitaire Grand Harvest
#   ✓ 16. Yu-Gi-Oh! Master Duel
#   ✓ 17. Gin Rummy Plus: Fun Card Game
#   ✓ 19. Skip-Bo™: Solitaire Card Game
#   ✓ 20. Phase 10: Casual Card Game
#   ✓ 21. Card Crawl Adventure
#   ✓ 22. Tiki Solitaire TriPeaks
#   ✓ 23. Microsoft Solitaire Collection
#   ✓ 26. Solitaire TriPeaks Journey
#   ✓ 27. Card Crawl
#   ✓ 29. Pokémon TCG Live
#   ✓ 30. Spades Stars - Card Game
#
# Searching: GAME_CASINO
#   ✓ 1. Coin Master
#   ✓ 2. Jackpot Party Casino Slots
#   ✓ 6. Zynga Poker- Texas Holdem Game
#   ✓ 7. DoubleDown Casino Vegas Slots
#   ✓ 8. Grand Cash Casino Slots Games
#   ✓ 9. Jackpotland-Vegas Casino Slots
#   ✓ 10. Jackpot Wins - Slots Casino
#   ✓ 12. GSN Casino: Slot Machine Games
#   ✓ 13. Animals & Coins Adventure Game
#   ✓ 14. Classic Slots™ - Casino Games
#   ✓ 15. MONOPOLY Poker - Texas Holdem
#   ✓ 16. Hard Rock Neverland Casino
#   ✓ 17. Live Play Bingo: Real Hosts
#   ✓ 18. House of Fun™ - Casino Slots
#   ✓ 19. WSOP Poker: Texas Holdem Game
#   ✓ 20. 88 Fortunes Casino Slot Games
#   ✓ 21. Bingo Pop: Play Live Online
#   ✓ 22. Bingo Frenzy™-Live Bingo Games
#   ✓ 23. Cash Tornado™ Slots - Casino
#   ✓ 24. Huuuge Casino 777 Slots Games
#   ✓ 25. Bingo Voyage - Live Bingo Game
#   ✓ 27. DoubleU Casino™ - Vegas Slots
#   ✓ 28. Scatter Slots - Slot Machines
#   ✓ 29. Lightning Link Casino Slots
#
# Searching: GAME_CASUAL
#   ✓ 2. Farm Heroes Saga
#   ✓ 4. Hay Day
#   ✓ 10. Best Fiends - Match 3 Puzzles
#   ✓ 15. Star Wars™: Galaxy of Heroes
#   ✓ 18. Dream League Soccer 2025
#   ✓ 20. Township
#   ✓ 21. Block Blast!
#   ✓ 22. My Talking Tom 2
#   ✓ 28. Avatar World ®
#   ✓ 29. SimCity BuildIt
#
# Searching: GAME_EDUCATIONAL
#   ✓ 1. LogicLike: ABC & Math for kids
#   ✓ 2. Kids Learning Educational Game
#   ✓ 3. ABC Kids - Tracing & Phonics
#   ✓ 5. Bebi: Baby Games for 2-4y kids
#   ✓ 6. Aha World: Doll Dress-Up Game
#   ✓ 8. Kiddopia - Kids Learning Games
#   ✓ 9. Kids Toddler & Preschool Games
#   ✓ 10. TinyTap: Kids' Learning Games
#   ✓ 11. Shapes: Toddler Learning Games
#
# Searching: GAME_MUSIC
#   ✓ 2. Rhythm Rush - Piano Music Game
#   ✓ 3. Drum Pad Machine - beat maker
#   ✓ 4. Lanota - Music game with story
#   ✓ 5. Piano Idol Star: Game Music
#   ✓ 6. Song Beat: Music Game
#   ✓ 7. Piano Music Party: Rhythm Game
#   ✓ 8. Music Tower: Tap Tiles
#   ✓ 9. Country Star
#   ✓ 10. Piano Music Go-EDM Piano Games
#   ✓ 11. Piano Game: Classic Music Song
#   ✓ 12. Groovepad - music & beat maker
#
# Searching: GAME_PUZZLE
#   ✓ 7. Jigsawscapes® - Jigsaw Puzzles
#   ✓ 8. Jigsaw Puzzles - Puzzle Games
#   ✓ 11. Sort Mania
#   ✓ 12. Puzzle SEVENTEEN
#   ✓ 15. Toon Blast
#   ✓ 17. Project Makeover
#   ✓ 18. Block Puzzle
#   ✓ 19. Block Puzzle
#   ✓ 21. Puzzle Kids: Jigsaw Puzzles
#   ✓ 23. Bubble Witch 2 Saga
#   ✓ 24. Toy Blast
#   ✓ 26. Angry Birds Journey
#   ✓ 27. Merge Dragons!
#   ✓ 30. Empires & Puzzles: Dragon Dawn
#
# Searching: GAME_RACING
#   ✓ 3. CSR 2 Realistic Drag Racing
#   ✓ 7. Hot Wheels Unlimited
#   ✓ 8. F1 Clash - Official F1 Game
#   ✓ 9. Disney Speedstorm
#   ✓ 10. CarX Street
#   ✓ 11. Hill Climb Racing
#   ✓ 12. Race Craft - Kids Car Games
#   ✓ 13. Traffic Rider
#   ✓ 14. Hot Slide
#   ✓ 16. Sonic Forces: PvP Battle Race
#   ✓ 17. Beach Buggy Racing 2
#   ✓ 18. Race Master 3D: Car Racing
#   ✓ 19. Real Racing 3
#   ✓ 20. Pixel Car Racer
#   ✓ 21. Beach Buggy Racing
#   ✓ 22. Alto's Odyssey
#   ✓ 23. CarX Highway Racing
#   ✓ 24. Alto's Adventure
#   ✓ 25. Drive Ahead! - Fun Car Battles
#   ✓ 26. Rival Stars Horse Racing
#   ✓ 27. Neon Runners: Craft & Dash
#   ✓ 28. Top Drives - Car Race Battles
#   ✓ 29. Fun Run 4 - Multiplayer Games
#   ✓ 30. Fun Run 3 - Multiplayer Games
#
# Searching: GAME_ROLE_PLAYING
# Gagal search keyword GAME_ROLE_PLAYING: 'NoneType' object is not subscriptable
#
# Searching: GAME_SIMULATION
#   ✓ 2. TSM
#   ✓ 6. Toca Boca World
#   ✓ 9. Fallout Shelter
#   ✓ 12. Egg, Inc.
#   ✓ 13. Love and Deepspace
#   ✓ 14. Dragon City: Mobile Adventure
#   ✓ 15. Idle Guy: Life Simulator games
#   ✓ 16. Minecraft: Dream it, Build it!
#   ✓ 18. Harvest Town
#   ✓ 19. My Singing Monsters
#   ✓ 20. PewDiePie's Tuber Simulator
#   ✓ 21. Sunrise Village: Farm Game
#   ✓ 22. PK XD: Fun, friends & games
#   ✓ 23. Bluey: Let's Play!
#   ✓ 25. Idle Miner Tycoon: Gold & Cash
#   ✓ 26. FarmVille 2: Country Escape
#   ✓ 27. Monster Legends
#   ✓ 28. My Talking Tom Friends
#   ✓ 29. My Talking Angela 2
#   ✓ 30. My Little Pony: Magic Princess
#
# Searching: GAME_SPORTS
#   ✓ 5. Basketball Stars: Multiplayer
#   ✓ 7. Basketball Rivals: Sports Game
#   ✓ 8. Basketball Slam MyTEAM
#   ✓ 10. Golf Rival - Multiplayer Game
#   ✓ 12. NFL 2K Playmakers Sports Cards
#   ✓ 13. Hoop Land
#   ✓ 14. Baseball Clash: Real-time game
#   ✓ 16. Ultimate Pro Hockey GM
#   ✓ 17. Ultimate Pro Basketball GM
#   ✓ 18. Tennis Clash: Multiplayer Game
#   ✓ 19. Olympics™ Go! Paris 2024
#   ✓ 20. Football Battle: Touchdown!
#   ✓ 21. Mini Basketball
#   ✓ 23. Hoop League Tactics
#   ✓ 24. Astonishing Basketball Manager
#   ✓ 25. Fiete Sports - 37 Sport Games
#   ✓ 26. Summer Sports Mania
#   ✓ 27. League Tycoon Fantasy Football
#   ✓ 28. Franchise Basketball: Pro GM
#   ✓ 29. Idle Sports Tycoon Game
#   ✓ 30. Basketball Superstar 2
#
# Searching: GAME_STRATEGY
#   ✓ 1. Boom Beach: War Strategy Game
#   ✓ 2. The Battle of Polytopia
#   ✓ 4. Art of War 3:RTS strategy game
#   ✓ 5. Last War:Survival Game
#   ✓ 6. Whiteout Survival
#   ✓ 7. Total Battle: War Strategy
#   ✓ 8. Rise of Kingdoms: Lost Crusade
#   ✓ 9. Supremacy: Call of War 1942
#   ✓ 10. LUDUS・Strategy PvP Battle Game
#   ✓ 11. Supremacy 1914 - WW1 Strategy
#   ✓ 12. The Walking Dead: Survivors
#   ✓ 13. Supremacy: World War 3
#   ✓ 16. Frost & Flame: King of Avalon
#   ✓ 17. Raid Rush: Tower Defense TD
#   ✓ 18. Infinity Kingdom
#   ✓ 19. Kingdom Rush Tower Defense TD
#   ✓ 20. Rush Royale: Tower Defense TD
#   ✓ 21. Age of Empires Mobile
#   ✓ 22. Call of Dragons
#   ✓ 23. Grand War: Rome Strategy Games
#   ✓ 24. EMERGENCY HQ: firefighter game
#   ✓ 25. War and Order
#   ✓ 26. World Conqueror 4-WW2 Strategy
#   ✓ 27. Star Trek™ Fleet Command
#   ✓ 28. March of Empires: War Games
#   ✓ 29. The Ants: Underground Kingdom
#   ✓ 30. Rebel Inc.
#
# Searching: GAME_TRIVIA
#   ✓ 1. Trivia Crack: Fun Quiz Games
#   ✓ 2. TRIVIA 360: Quiz Game
#   ✓ 3. Jeopardy!® Trivia TV Game Show
#   ✓ 4. Trivia Spin－Guess Brain Quiz
#   ✓ 5. Trivia Crush
#   ✓ 6. QuizzLand. Quiz & Trivia game
#   ✓ 7. Trivia Crack 2
#   ✓ 8. Erudite: Trivia Games & Quiz
#   ✓ 9. QuizDuel! Quiz & Trivia Game
#   ✓ 10. Trivia Games
#   ✓ 11. Official Millionaire Game
#
# Searching: GAME_WORD
#   ✓ 1. Word Roll
#   ✓ 2. Word Galaxy Challenge
#   ✓ 3. Wordscapes
#   ✓ 4. Word Connect
#   ✓ 5. Zen Word® - Relax Puzzle Game
#   ✓ 6. Words With Friends Word Game
#   ✓ 7. Word Connect - Words of Nature
#   ✓ 8. Word Wars - Word Game
#   ✓ 9. Word Connect - Offline
#   ✓ 10. Word Trip - Word Puzzle Game
#   ✓ 11. Game of Words: Word Puzzles
#   ✓ 12. Word Crush - Fun Puzzle Game
#   ✓ 13. Word Cookies! ®
#   ✓ 14. Classic Words With Friends
#   ✓ 16. Word Bliss
#   ✓ 17. Word Search
#   ✓ 18. Wordzee! - Puzzle Word Game
#   ✓ 19. Easy Words - Word Puzzle Games
#   ✓ 20. Word Search
#   ✓ 21. Word Tour
#   ✓ 22. Word Serenity: Fun Word Search
#   ✓ 23. Languinis: Word Game
#   ✓ 24. Crossword Master - Word Puzzle
#   ✓ 26. Word Tower: Relaxing Word Game
#   ✓ 27. Word Connect - Train Brain
#   ✓ 28. Word Charm
#   ✓ 29. Word Domination
#   ✓ 30. Word Life - Crossword puzzle
#
# Searching: FAMILY_ACTION
#   ✓ 1. 575 Family Action Space
#   ✓ 2. Parental Control App- FamiSafe
#   ✓ 10. Family Tools: Family Organizer
#
# Searching: FAMILY_BRAINGAMES
# Gagal search keyword FAMILY_BRAINGAMES: 'NoneType' object is not subscriptable
#
# Searching: FAMILY_CREATE
#   ✓ 4. Maple (beta)
#   ✓ 5. Dice With Buddies™ Social Game
#   ✓ 6. Mint Mobile
#   ✓ 8. Florescence: Merge Garden
#   ✓ 12. TC Connect
#   ✓ 15. OctoStudio
#   ✓ 16. Nosher: Healthy Food Scanner
#   ✓ 17. Vlad&Niki Town. It's my World
#   ✓ 18. Dream Family - Home Design
#   ✓ 19. Take Part - Virtual Guestbook
#   ✓ 20. BillOut - Bill Organizer
#   ✓ 21. TruPlay: Christian Games
#   ✓ 22. JagBandhu: Event Planner
#   ✓ 23. Thriftique Marketplace
#   ✓ 24. Scratch
#   ✓ 25. Такси Люкс Богородицк Кимовск
#   ✓ 26. NorthShoreConnect
#   ✓ 27. Binumi
#   ✓ 28. ElvoKidz
#   ✓ 29. Muud: Müzik dinle & indir
#   ✓ 30. Такси-Байкал
#
#  Selesai! Total aplikasi unik: 1493

# %%
# Simpan ke file
with open('google_play_scraped_20x68.json', 'w', encoding='utf-8') as f:
    json.dump(list(all_apps.values()), f, ensure_ascii=False, indent=4)

print(f"\n Selesai! Total aplikasi unik: {len(all_apps)}")
# Out:
#  Selesai! Total aplikasi unik: 1493
